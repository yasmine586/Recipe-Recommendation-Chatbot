# %%
import pandas as pd
df=pd.read_csv("recipes_data.csv",nrows=1000000)

# %%
df.nunique()
# Out:
# title           7194
# ingredients     9999
# directions      9989
# link           10000
# source             1
# NER             9807
# site               1
# dtype: int64

# %%
df.describe()
# Out:
#                     title                                        ingredients  \
# count               10000                                              10000
# unique               7194                                               9999
# top     Chicken Casserole  ["1 pkg. fudge cake mix", "1 (21 oz.) can cher...
# freq                   55                                                  2
#
#                          directions  \
# count                         10000
# unique                         9989
# top     ["Mix together and chill."]
# freq                              4
#
#                                                   link    source  \
# count                                            10000     10000
# unique                                           10000         1
# top     www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# freq                                                 1     10000
#
# ...

# %%
df[df["NER"].str.len()<20]
# Out:
#                                         title  \
# 530                           Pigs In Blanket
# 716                            Party Potatoes
# 1256                               Beer Bread
# 1305                               Beer Bread
# 1448                      Pork Shoulder Roast
# ...                                       ...
# 999225                             Fire Eater
# 999378                           Carrot Blush
# 999648  Stranger Things Candy Carton Assembly
# 999765                    Prosciutto E Melone
# 999783                             Jelly Whip
#
#                                               ingredients  \
# 530     ["1 pkg. cocktail hot dogs", "5 cans crescent ...
# 716     ["4 c. mashed potatoes", "1 pkg. Hidden Valley...
# 1256    ["3 c. self-rising flour", "2 Tbsp. sugar (3 i...
# 1305    ["2 2/3 c. self-rising flour", "12 oz. beer, f...
# 1448                               ["roast (3 to 5 lb.)"]
# ...

# %%
df=pd.read_csv("recipes_preprocessed_ner.csv")
df.head()
# Out:
#                    title                                         directions  \
# 0    No-Bake Nut Cookies  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  Jewell Ball'S Chicken  ["Place chipped beef on bottom of baking dish....
# 2            Creamy Corn  ["In a slow cooker, combine all ingredients. C...
# 3          Chicken Funny  ["Boil and debone chicken.", "Put bite size pi...
# 4   Reeses Cups(Candy)    ["Combine first four ingredients and press in ...
#
#                                             NER_flat  \
# 0  bite size shredded rice biscuits vanilla brown...
# 1  cream of mushroom soup beef sour cream chicken...
# 2  frozen corn pepper cream cheese garlic powder ...
# 3  chicken gravy cream of mushroom soup chicken s...
# 4  graham cracker crumbs powdered sugar peanut bu...
#
#                                               link  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=44874
# 1  www.cookbooks.com/Recipe-Details.aspx?id=699419
# ...
